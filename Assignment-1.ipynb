# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

# %%
#Read the dataset to python environment.

# %%
dataset = pd.read_excel('iris.xls')

# %%
#Display the columns in the dataset

# %%
dataset.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#Calculate the mean of each column of the dataset.

# %%
dataset.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#Check for the null values present in the dataset.

# %%
dataset.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#Perform meaningful visualizations using the dataset. Bring at least 3 visualizations

# %%
plt.figure()
plt.scatter(dataset['SL'],dataset['SW'],s=10)
plt.title('SL vs SW')
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
plt.figure(figsize=(8,8))
dataset[['PL','PW']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.pairplot(dataset)

# %%
sns.boxplot(x='SL',y='SW',data=dataset)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
sns.swarmplot(x='PW',y='PL',data=dataset)
# Out:
# C:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.countplot(dataset['Classification'])
# Out:
# C:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Classification', ylabel='count'>
